# %%
import pandas as pd
import requests
url = 'https://coinmarketcap.com/currencies/bitcoin/historical-data/?start=20160425&end=20180425'
test_df = pd.read_html(requests.get(url,headers={'User-agent': 'Mozilla/5.0'}).text)[0]
test_df.head(5)
# Out:
#            Date     Open     High      Low    Close       Volume    Market Cap
# 0  Apr 25, 2018  9701.03  9745.32  8799.84  8845.74  11083100000  164893000000
# 1  Apr 24, 2018  8934.34  9732.61  8927.83  9697.50  10678800000  151844000000
# 2  Apr 23, 2018  8794.39  8958.55  8788.81  8930.88   6925190000  149448000000
# 3  Apr 22, 2018  8925.06  9001.64  8779.61  8802.46   6629900000  151651000000
# 4  Apr 21, 2018  8848.79  8997.57  8652.15  8895.58   7548550000  150337000000

# %%
test_df.set_index('Date')
# Out:
#                  Open     High      Low    Close       Volume    Market Cap
# Date
# Apr 25, 2018  9701.03  9745.32  8799.84  8845.74  11083100000  164893000000
# Apr 24, 2018  8934.34  9732.61  8927.83  9697.50  10678800000  151844000000
# Apr 23, 2018  8794.39  8958.55  8788.81  8930.88   6925190000  149448000000
# Apr 22, 2018  8925.06  9001.64  8779.61  8802.46   6629900000  151651000000
# Apr 21, 2018  8848.79  8997.57  8652.15  8895.58   7548550000  150337000000
# Apr 20, 2018  8286.88  8880.23  8244.54  8845.83   8438110000  140777000000
# Apr 19, 2018  8159.27  8298.69  8138.78  8294.31   7063210000  138591000000
# Apr 18, 2018  7944.43  8197.80  7886.01  8163.42   6529910000  134926000000
# Apr 17, 2018  8071.66  8285.96  7881.72  7902.09   6900880000  137070000000
# Apr 16, 2018  8337.57  8371.15  7925.73  8058.67   5631310000  141571000000
# Apr 15, 2018  7999.33  8338.42  7999.33  8329.11   5244480000  135812000000
# ...

# %%
url = 'https://coinmarketcap.com/currencies/ethereum/historical-data/?start=20160425&end=20180425'
df_ethereum = pd.read_html(requests.get(url,headers={'User-agent': 'Mozilla/5.0'}).text)[0]
df_ethereum.set_index('Date')
df_ethereum.rename(columns={'Close': 'Ethereum Close'}, inplace=True)
print(df_ethereum)
# Out:
#              Date    Open    High     Low  Ethereum Close      Volume  \
# 0    Apr 25, 2018  707.06  707.06  600.21          615.42  4216140000
# 1    Apr 24, 2018  643.40  708.88  643.40          708.16  3581860000
# 2    Apr 23, 2018  621.20  646.70  621.03          642.55  2386830000
# 3    Apr 22, 2018  606.12  640.77  593.87          621.86  2426270000
# 4    Apr 21, 2018  616.00  621.89  578.55          605.39  2612460000
# 5    Apr 20, 2018  567.99  618.72  560.28          615.72  2849470000
# 6    Apr 19, 2018  524.04  567.89  523.26          567.89  2256870000
# 7    Apr 18, 2018  503.31  525.09  503.05          524.79  1762940000
# 8    Apr 17, 2018  511.14  518.03  502.56          502.89  1760360000
# 9    Apr 16, 2018  532.07  534.20  500.25          511.15  1758980000
# 10   Apr 15, 2018  502.88  531.70  502.88          531.70  1726090000
# 11   Apr 14, 2018  492.58  512.02  488.28          501.48  1519080000
# ...

# %%
url = 'https://coinmarketcap.com/currencies/bitcoin/historical-data/?start=20160425&end=20180425'
df_bitcoin = pd.read_html(requests.get(url,headers={'User-agent': 'Mozilla/5.0'}).text)[0]
df_bitcoin.set_index('Date')
df_bitcoin.rename(columns={'Close': 'Bitcoin Close'}, inplace=True)

url = 'https://coinmarketcap.com/currencies/ethereum/historical-data/?start=20160425&end=20180425'
df_ethereum = pd.read_html(requests.get(url,headers={'User-agent': 'Mozilla/5.0'}).text)[0]
df_ethereum.set_index('Date')
df_ethereum.rename(columns={'Close': 'Ethereum Close'}, inplace=True)

url = 'https://coinmarketcap.com/currencies/ripple/historical-data/?start=20160425&end=20180425'
df_ripple = pd.read_html(requests.get(url,headers={'User-agent': 'Mozilla/5.0'}).text)[0]
df_ripple.set_index('Date')
df_ripple.rename(columns={'Close': 'Ripple Close'}, inplace=True)

url = 'https://coinmarketcap.com/currencies/bitcoin-cash/historical-data/?start=20160425&end=20180425'
df_bitcoincash = pd.read_html(requests.get(url,headers={'User-agent': 'Mozilla/5.0'}).text)[0]
df_bitcoincash.set_index('Date')
df_bitcoincash.rename(columns={'Close': 'Bitcoincash Close'}, inplace=True)

url = 'https://coinmarketcap.com/currencies/eos/historical-data/?start=20160425&end=20180425'
df_eos = pd.read_html(requests.get(url,headers={'User-agent': 'Mozilla/5.0'}).text)[0]
df_eos.set_index('Date')
df_eos.rename(columns={'Close': 'Eos Close'}, inplace=True)

url = 'https://coinmarketcap.com/currencies/cardano/historical-data/?start=20160425&end=20180425'
df_cardano = pd.read_html(requests.get(url,headers={'User-agent': 'Mozilla/5.0'}).text)[0]
df_cardano.set_index('Date')
df_cardano.rename(columns={'Close': 'Cardano Close'}, inplace=True)

url = 'https://coinmarketcap.com/currencies/litecoin/historical-data/?start=20160425&end=20180425'
df_litecoin = pd.read_html(requests.get(url,headers={'User-agent': 'Mozilla/5.0'}).text)[0]
df_litecoin.set_index('Date')
df_litecoin.rename(columns={'Close': 'Litecoin Close'}, inplace=True)

url = 'https://coinmarketcap.com/currencies/stellar/historical-data/?start=20160425&end=20180425'
df_stellar = pd.read_html(requests.get(url,headers={'User-agent': 'Mozilla/5.0'}).text)[0]
df_stellar.set_index('Date')
df_stellar.rename(columns={'Close': 'Stellar Close'}, inplace=True)

url = 'https://coinmarketcap.com/currencies/iota/historical-data/?start=20160425&end=20180425'
df_iota = pd.read_html(requests.get(url,headers={'User-agent': 'Mozilla/5.0'}).text)[0]
df_iota.set_index('Date')
df_iota.rename(columns={'Close': 'Iota Close'}, inplace=True)

url = 'https://coinmarketcap.com/currencies/tron/historical-data/?start=20160425&end=20180425'
df_tron = pd.read_html(requests.get(url,headers={'User-agent': 'Mozilla/5.0'}).text)[0]
df_tron.set_index('Date')
df_tron.rename(columns={'Close': 'Tron Close'}, inplace=True)

url = 'https://coinmarketcap.com/currencies/neo/historical-data/?start=20160425&end=20180425'
df_neo = pd.read_html(requests.get(url,headers={'User-agent': 'Mozilla/5.0'}).text)[0]
df_neo.set_index('Date')
df_neo.rename(columns={'Close': 'Neo Close'}, inplace=True)

url = 'https://coinmarketcap.com/currencies/dash/historical-data/?start=20160425&end=20180425'
df_dash = pd.read_html(requests.get(url,headers={'User-agent': 'Mozilla/5.0'}).text)[0]
df_dash.set_index('Date')
df_dash.rename(columns={'Close': 'Dash Close'}, inplace=True)

url = 'https://coinmarketcap.com/currencies/nem/historical-data/?start=20160425&end=20180425'
df_nem = pd.read_html(requests.get(url,headers={'User-agent': 'Mozilla/5.0'}).text)[0]
df_nem.set_index('Date')
df_nem.rename(columns={'Close': 'Nem Close'}, inplace=True)

url = 'https://coinmarketcap.com/currencies/monero/historical-data/?start=20160425&end=20180425'
df_monero = pd.read_html(requests.get(url,headers={'User-agent': 'Mozilla/5.0'}).text)[0]
df_monero.set_index('Date')
df_monero.rename(columns={'Close': 'Monero Close'}, inplace=True)

url = 'https://coinmarketcap.com/currencies/vechain/historical-data/?start=20160425&end=20180425'
df_vechain = pd.read_html(requests.get(url,headers={'User-agent': 'Mozilla/5.0'}).text)[0]
df_vechain.set_index('Date')
df_vechain.rename(columns={'Close': 'VeChain Close'}, inplace=True)

url = 'https://coinmarketcap.com/currencies/tether/historical-data/?start=20160425&end=20180425'
df_tether = pd.read_html(requests.get(url,headers={'User-agent': 'Mozilla/5.0'}).text)[0]
df_tether.set_index('Date')
df_tether.rename(columns={'Close': 'Tether Close'}, inplace=True)

url = 'https://coinmarketcap.com/currencies/lisk/historical-data/?start=20160425&end=20180425'
df_lisk = pd.read_html(requests.get(url,headers={'User-agent': 'Mozilla/5.0'}).text)[0]
df_lisk.set_index('Date')
df_lisk.rename(columns={'Close': 'Lisk Close'}, inplace=True)

url = 'https://coinmarketcap.com/currencies/bytecoin-bcn/historical-data/?start=20160425&end=20180425'
df_bytecoin = pd.read_html(requests.get(url,headers={'User-agent': 'Mozilla/5.0'}).text)[0]
df_bytecoin.set_index('Date')
df_bytecoin.rename(columns={'Close': 'Bytecoin Close'}, inplace=True)

url = 'https://coinmarketcap.com/currencies/verge/historical-data/?start=20160425&end=20180425'
df_verge = pd.read_html(requests.get(url,headers={'User-agent': 'Mozilla/5.0'}).text)[0]
df_verge.set_index('Date')
df_verge.rename(columns={'Close': 'Verge Close'}, inplace=True)

url = 'https://coinmarketcap.com/currencies/steem/historical-data/?start=20160425&end=20180425'
df_steem = pd.read_html(requests.get(url,headers={'User-agent': 'Mozilla/5.0'}).text)[0]
df_steem.set_index('Date')
df_steem.rename(columns={'Close': 'Steem Close'}, inplace=True)

url = 'https://coinmarketcap.com/currencies/siacoin/historical-data/?start=20160425&end=20180425'
df_siacoin = pd.read_html(requests.get(url,headers={'User-agent': 'Mozilla/5.0'}).text)[0]
df_siacoin.set_index('Date')
df_siacoin.rename(columns={'Close': 'Siacoin Close'}, inplace=True)

url = 'https://coinmarketcap.com/currencies/bitshares/historical-data/?start=20160425&end=20180425'
df_bitshares = pd.read_html(requests.get(url,headers={'User-agent': 'Mozilla/5.0'}).text)[0]
df_bitshares.set_index('Date')
df_bitshares.rename(columns={'Close': 'Bitshares Close'}, inplace=True)

# %%
result = pd.concat([df_bitcoin['Bitcoin Close'], df_ethereum['Ethereum Close'],df_ripple['Ripple Close'],df_tether['Tether Close'],
                   df_lisk['Lisk Close'],df_bytecoin['Bytecoin Close'],df_litecoin['Litecoin Close'],df_stellar['Stellar Close'],
                   df_verge['Verge Close'],df_steem['Steem Close'],df_siacoin['Siacoin Close'],df_dash['Dash Close'],df_nem['Nem Close'],
                   df_monero['Monero Close'],df_bitshares['Bitshares Close']], axis=1)
#result.set_index('Date')
print(result)
# Out:
#      Bitcoin Close  Ethereum Close  Ripple Close  Tether Close  Lisk Close  \
# 0          8845.74          615.42      0.800607      0.991809   11.050000
# 1          9697.50          708.16      0.934781      1.000000   13.090000
# 2          8930.88          642.55      0.876657      0.997847   12.300000
# 3          8802.46          621.86      0.869995      0.996196   11.530000
# 4          8895.58          605.39      0.873103      0.999014   11.660000
# 5          8845.83          615.72      0.924465      0.998338   12.320000
# 6          8294.31          567.89      0.791976      0.997185   11.780000
# 7          8163.42          524.79      0.708932      0.997609   11.310000
# 8          7902.09          502.89      0.656933      0.998556   10.480000
# 9          8058.67          511.15      0.663297      0.997592   10.690000
# 10         8329.11          531.70      0.682534      0.998602   10.480000
# ...

# %%
url = 'https://coinmarketcap.com/currencies/tether/historical-data/?start=20160425&end=20180425'
df_tether = pd.read_html(requests.get(url,headers={'User-agent': 'Mozilla/5.0'}).text)[0]
df_tether.set_index('Date')
df_tether.rename(columns={'Close': 'tether Close'}, inplace=True)
df_tether[::-1]
df_tether[::-1].head
# Out:
# <bound method NDFrame.head of              Date      Open  High       Low  tether Close      Volume  \
# 730  Apr 25, 2016  1.000000  1.00  1.000000      1.000000      298864
# 729  Apr 26, 2016  1.000000  1.00  1.000000      1.000000      515109
# 728  Apr 27, 2016  1.000000  1.00  1.000000      1.000000      481952
# 727  Apr 28, 2016  1.000000  1.00  1.000000      1.000000      544476
# 726  Apr 29, 2016  1.000000  1.00  1.000000      1.000000      146006
# 725  Apr 30, 2016  1.000000  1.00  1.000000      1.000000      454278
# 724  May 01, 2016  1.000000  1.00  1.000000      1.000000       49006
# 723  May 02, 2016  1.000000  1.00  1.000000      1.000000      193440
# 722  May 03, 2016  1.000000  1.00  1.000000      1.000000      408428
# 721  May 04, 2016  1.000000  1.00  1.000000      1.000000      215176
# 720  May 05, 2016  1.000000  1.00  1.000000      1.000000      753773
# 719  May 06, 2016  1.000000  1.00  1.000000      1.000000     2747610
# ...

# %%
# Out:
# <bound method NDFrame.head of              Date      Open      High       Low  VeChain Close     Volume  \
# 0    Apr 25, 2018  4.140000  4.180000  3.560000       3.620000   82778500
# 1    Apr 24, 2018  3.890000  4.190000  3.890000       4.170000  107471000
# 2    Apr 23, 2018  3.830000  3.950000  3.810000       3.880000   83179700
# 3    Apr 22, 2018  3.860000  3.980000  3.770000       3.830000   85951500
# 4    Apr 21, 2018  3.950000  3.960000  3.590000       3.840000   80985400
# 5    Apr 20, 2018  3.730000  3.960000  3.630000       3.930000   89724600
# 6    Apr 19, 2018  3.570000  3.730000  3.520000       3.710000   83805600
# 7    Apr 18, 2018  3.310000  3.610000  3.280000       3.580000   83240100
# 8    Apr 17, 2018  3.340000  3.450000  3.290000       3.300000   68839900
# 9    Apr 16, 2018  3.550000  3.590000  3.250000       3.350000   78060300
# 10   Apr 15, 2018  3.290000  3.560000  3.290000       3.560000   80133900
# ...
